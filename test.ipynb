# %%
# %matplotlib inline
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

norm = stats.norm(1500, 500)

xs = np.linspace(500, 2500, 200)
ys = norm.pdf(xs)

plt.plot(xs, ys, linewidth=10)
